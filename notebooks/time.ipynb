# %% [markdown]
# ## Data Analysis (Ice Measurements)
# - Pandas: [Time Series Analysis](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#time-series-date-functionality)

# %%
# Import the necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Source: https://www.nenanaakiceclassic.com/ice")
# Out:
# Source: https://www.nenanaakiceclassic.com/ice

# %%
# Read in the data (CSV)
df = pd.read_csv("../data/IceMeasurements_1989-2022.csv")

df.head()
# Out:
#   Date (YYYY-MM-DD)  Measurement (Inches)
# 0        2022-01-11                  27.0
# 1        2022-02-14                  28.5
# 2        2022-02-28                  31.7
# 3        2022-03-06                  27.0
# 4        2022-03-14                  29.7

# %%
# Rename the columns
date = df.rename(columns={'Date (YYYY-MM-DD)': 'date'})
thickness = df.rename(columns={'Measurement (Inches)': 'thickness'})

# Create a new dataframe
df_new = pd.concat([date, thickness], axis=1)

# Sort the dataframe by date
df_new = df_new.sort_values(by='date')

# Plot the data
df_new.plot(x='date', y='thickness', kind='line')

# Plotting date vs. ice thickness
plt.xlabel('Date (YYYY-MM-DD)')
plt.ylabel('Ice Thickness (inches)')

# Add a title
plt.title('Ice Measurements (1989-2022)')
# Out:
# Text(0.5, 1.0, 'Ice Measurements (1989-2022)')

# %%
# TODO: Compare each year to the previous set of measurements.
